# %%
# %run split_new.py
# Out:
# 正在处理类别 [1] 的图片...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:12<00:00,  2.24it/s]
# 正在处理类别 [2] 的图片...
# 100%|████████████████████████████████████████████████████████████████████████████████| 150/150 [01:07<00:00,  2.21it/s]
# 正在处理类别 [3] 的图片...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:23<00:00,  2.12it/s]
# 正在处理类别 [4] 的图片...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [00:20<00:00,  2.08it/s]
# ✅ 所有竖向图片切分完成！已按要求处理宽度并记录坐标。

# %%
import torch
import torchvision.models as models
import torch.nn as nn

# 加载模型
model = models.resnet18(pretrained=False)
model.fc = nn.Linear(model.fc.in_features, 4)
checkpoint = torch.load('best_ordinal_resnet18.pth')
model.load_state_dict(checkpoint)
model.eval()

# 导出为 ONNX 文件
dummy_input = torch.randn(1, 3, 224, 224)
torch.onnx.export(model, dummy_input, "my_ordinal_resnet18.onnx")
print("模型已导出为 my_ordinal_resnet18.onnx")
# Out:
# 模型已导出为 my_ordinal_resnet18.onnx
