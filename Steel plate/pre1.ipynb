# %%
# 数据预处理,检查所有照片的size

# %%
import os
from PIL import Image

def check_images_detailed(folder_path):
    max_height=-1
    max_width=-1
    print(f"正在深度扫描文件夹: {folder_path} ...\n")
    # 调整一下表头格式，让输出对齐更漂亮
    header = f"{'文件名':<30} | {'尺寸 (宽x高)':<15} | {'通道数':<6} | {'模式':<6}"
    print(header)
    print("-" * 70)

    count = 0
    # 统计一下通道类型的分布，方便最后看概览
    channel_stats = {} 

    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith('.bmp'):
                file_path = os.path.join(root, file)
                
                try:
                    with Image.open(file_path) as img:
                        width, height = img.size
                        # --- 核心修改部分 ---
                        # img.getbands() 返回一个元组，如 ('R', 'G', 'B') 或 ('L',)
                        channels = len(img.getbands()) 
                        
                        # img.mode 返回模式字符串，如 "RGB", "L" (灰度), "1" (二值), "CMYK"
                        mode = img.mode
                        
                        # 记录统计信息
                        if channels not in channel_stats:
                            channel_stats[channels] = 0
                        channel_stats[channels] += 1

                        # 格式化输出
                        size_str = f"{width}*{height}"
                        print(f"{file:<30} | {size_str:<15} | {channels:<6} | {mode:<6}")
                        count += 1
                        
                except Exception as e:
                    print(f"[错误] 无法读取文件 {file}: {e}")
    print("最大宽度:"+str(max_width))
    print("最大高度:"+str(max_height))
    print("-" * 70)
    print(f"扫描完成，共 {count} 张图片。")
    print(f"通道分布统计: {channel_stats}")
    # 例如: {1: 300, 3: 1500} 表示有300张单通道图，1500张三通道图

if __name__ == '__main__':
    # --- 修改这里：你的图片文件夹路径 ---
    base_folder = r"D:\FL\ignore\initial" 
    for i in range(1,5):
        target_folder = base_folder+"\\"+str(i)+"\\"
        print(target_folder)
        if os.path.exists(target_folder):
            check_images_detailed(target_folder)
        else:
            print("错误：找不到指定的文件夹路径")
# Out:
# D:\FL\ignore\initial\1\
# 正在深度扫描文件夹: D:\FL\ignore\initial\1\ ...
#
# 文件名                            | 尺寸 (宽x高)        | 通道数    | 模式
# ----------------------------------------------------------------------
# 1-1.bmp                        | 100*16314       | 3      | RGB
# 1-10.bmp                       | 124*16477       | 3      | RGB
# 1-11.bmp                       | 145*16229       | 3      | RGB
# 1-12.bmp                       | 161*16631       | 3      | RGB
# 1-13.bmp                       | 88*16588        | 3      | RGB
# 1-14.bmp                       | 115*16343       | 3      | RGB
# 1-15.bmp                       | 120*15638       | 3      | RGB
# 1-16.bmp                       | 135*16328       | 3      | RGB
# 1-17.bmp                       | 121*16384       | 3      | RGB
# 1-18.bmp                       | 139*16160       | 3      | RGB
# 1-19.bmp                       | 142*16475       | 3      | RGB
# 1-2.bmp                        | 120*16541       | 3      | RGB
# 1-20.bmp                       | 175*16756       | 3      | RGB
# 1-21.bmp                       | 170*16626       | 3      | RGB
# 1-22.bmp                       | 110*16683       | 3      | RGB
# 1-23.bmp                       | 139*16241       | 3      | RGB
# 1-24.bmp                       | 164*15639       | 3      | RGB
# 1-25.bmp                       | 168*16189       | 3      | RGB
# 1-26.bmp                       | 153*16300       | 3      | RGB
# 1-27.bmp                       | 171*16718       | 3      | RGB
# 1-28.bmp                       | 177*16718       | 3      | RGB
# 1-29.bmp                       | 161*16576       | 3      | RGB
# 1-3.bmp                        | 132*16178       | 3      | RGB
# 1-4.bmp                        | 131*16285       | 3      | RGB
# 1-5.bmp                        | 119*16379       | 3      | RGB
# 1-6.bmp                        | 131*16421       | 3      | RGB
# 1-7.bmp                        | 124*16720       | 3      | RGB
# 1-8.bmp                        | 122*16236       | 3      | RGB
# 1-9.bmp                        | 135*15819       | 3      | RGB
# ----------------------------------------------------------------------
# 扫描完成，共 29 张图片。
# 通道分布统计: {3: 29}
# D:\FL\ignore\initial\2\
# 正在深度扫描文件夹: D:\FL\ignore\initial\2\ ...
#
# 文件名                            | 尺寸 (宽x高)        | 通道数    | 模式
# ----------------------------------------------------------------------
# 2-1.bmp                        | 222*16390       | 3      | RGB
# 2-10.bmp                       | 155*16182       | 3      | RGB
# 2-100.bmp                      | 137*16752       | 3      | RGB
# 2-101.bmp                      | 150*15976       | 3      | RGB
# 2-102.bmp                      | 155*16741       | 3      | RGB
# 2-103.bmp                      | 143*16740       | 3      | RGB
# 2-104.bmp                      | 132*15923       | 3      | RGB
# 2-105.bmp                      | 175*16380       | 3      | RGB
# 2-106.bmp                      | 151*16256       | 3      | RGB
# 2-107.bmp                      | 142*16179       | 3      | RGB
# 2-108.bmp                      | 139*16176       | 3      | RGB
# 2-109.bmp                      | 141*16166       | 3      | RGB
# 2-11.bmp                       | 120*16560       | 3      | RGB
# 2-110.bmp                      | 148*16413       | 3      | RGB
# 2-111.bmp                      | 144*16057       | 3      | RGB
# 2-112.bmp                      | 138*16372       | 3      | RGB
# 2-113.bmp                      | 134*16888       | 3      | RGB
# 2-114.bmp                      | 137*16212       | 3      | RGB
# 2-115.bmp                      | 127*16645       | 3      | RGB
# 2-116.bmp                      | 142*16759       | 3      | RGB
# 2-117.bmp                      | 147*16463       | 3      | RGB
# 2-118.bmp                      | 155*16733       | 3      | RGB
# 2-119.bmp                      | 138*16379       | 3      | RGB
# 2-12.bmp                       | 144*16133       | 3      | RGB
# 2-120.bmp                      | 138*16483       | 3      | RGB
# 2-121.bmp                      | 170*16587       | 3      | RGB
# 2-122.bmp                      | 167*16344       | 3      | RGB
# 2-123.bmp                      | 138*16097       | 3      | RGB
# 2-124.bmp                      | 146*16191       | 3      | RGB
# 2-125.bmp                      | 139*15991       | 3      | RGB
# 2-126.bmp                      | 139*16409       | 3      | RGB
# 2-127.bmp                      | 165*16051       | 3      | RGB
# 2-128.bmp                      | 147*16002       | 3      | RGB
# 2-129.bmp                      | 166*16138       | 3      | RGB
# 2-13.bmp                       | 157*16152       | 3      | RGB
# 2-130.bmp                      | 154*16364       | 3      | RGB
# 2-131.bmp                      | 131*16125       | 3      | RGB
# 2-132.bmp                      | 177*16281       | 3      | RGB
# 2-133.bmp                      | 180*16085       | 3      | RGB
# 2-134.bmp                      | 135*16266       | 3      | RGB
# 2-135.bmp                      | 157*16364       | 3      | RGB
# 2-136.bmp                      | 136*16429       | 3      | RGB
# 2-137.bmp                      | 158*16434       | 3      | RGB
# 2-138.bmp                      | 152*16594       | 3      | RGB
# 2-139.bmp                      | 133*16189       | 3      | RGB
# 2-14.bmp                       | 155*16109       | 3      | RGB
# 2-140.bmp                      | 154*16208       | 3      | RGB
# 2-141.bmp                      | 151*16131       | 3      | RGB
# 2-142.bmp                      | 135*16159       | 3      | RGB
# 2-143.bmp                      | 132*16413       | 3      | RGB
# 2-144.bmp                      | 118*16199       | 3      | RGB
# 2-145.bmp                      | 137*16208       | 3      | RGB
# 2-146.bmp                      | 132*16738       | 3      | RGB
# 2-147.bmp                      | 146*16759       | 3      | RGB
# 2-148.bmp                      | 135*16275       | 3      | RGB
# 2-149.bmp                      | 128*16347       | 3      | RGB
# 2-15.bmp                       | 140*16019       | 3      | RGB
# 2-150.bmp                      | 134*16154       | 3      | RGB
# 2-151.bmp                      | 137*16418       | 3      | RGB
# 2-152.bmp                      | 153*16726       | 3      | RGB
# 2-16.bmp                       | 160*16157       | 3      | RGB
# 2-17.bmp                       | 131*16699       | 3      | RGB
# 2-18.bmp                       | 163*16127       | 3      | RGB
# 2-19.bmp                       | 147*16303       | 3      | RGB
# 2-2.bmp                        | 134*16408       | 3      | RGB
# 2-20.bmp                       | 113*16542       | 3      | RGB
# 2-21.bmp                       | 159*16193       | 3      | RGB
# 2-22.bmp                       | 96*16502        | 3      | RGB
# 2-23.bmp                       | 146*16063       | 3      | RGB
# 2-24.bmp                       | 134*16182       | 3      | RGB
# 2-25.bmp                       | 130*16643       | 3      | RGB
# 2-26.bmp                       | 104*16119       | 3      | RGB
# 2-27.bmp                       | 154*16255       | 3      | RGB
# 2-28.bmp                       | 254*15957       | 3      | RGB
# 2-29.bmp                       | 147*16134       | 3      | RGB
# 2-3.bmp                        | 128*16421       | 3      | RGB
# 2-30.bmp                       | 156*16022       | 3      | RGB
# 2-31.bmp                       | 132*16462       | 3      | RGB
# 2-32.bmp                       | 233*16100       | 3      | RGB
# 2-33.bmp                       | 153*16439       | 3      | RGB
# 2-34.bmp                       | 208*16253       | 3      | RGB
# 2-35.bmp                       | 240*16600       | 3      | RGB
# 2-36.bmp                       | 102*16689       | 3      | RGB
# 2-37.bmp                       | 254*15936       | 3      | RGB
# 2-38.bmp                       | 107*16568       | 3      | RGB
# 2-39.bmp                       | 188*15852       | 3      | RGB
# 2-4.bmp                        | 125*16439       | 3      | RGB
# 2-40.bmp                       | 189*16702       | 3      | RGB
# 2-41.bmp                       | 200*16130       | 3      | RGB
# 2-42.bmp                       | 160*16599       | 3      | RGB
# 2-45.bmp                       | 183*15754       | 3      | RGB
# 2-46.bmp                       | 229*16665       | 3      | RGB
# 2-47.bmp                       | 106*16631       | 3      | RGB
# 2-48.bmp                       | 176*15878       | 3      | RGB
# 2-49.bmp                       | 171*15937       | 3      | RGB
# 2-5.bmp                        | 96*16200        | 3      | RGB
# 2-50.bmp                       | 144*16501       | 3      | RGB
# 2-51.bmp                       | 136*16045       | 3      | RGB
# 2-52.bmp                       | 134*15667       | 3      | RGB
# 2-53.bmp                       | 115*17367       | 3      | RGB
# 2-54.bmp                       | 133*16157       | 3      | RGB
# 2-55.bmp                       | 142*15894       | 3      | RGB
# 2-56.bmp                       | 110*16575       | 3      | RGB
# 2-57.bmp                       | 132*15573       | 3      | RGB
# 2-58.bmp                       | 254*16312       | 3      | RGB
# 2-59.bmp                       | 125*16191       | 3      | RGB
# 2-6.bmp                        | 129*16519       | 3      | RGB
# 2-60.bmp                       | 237*16191       | 3      | RGB
# 2-61.bmp                       | 232*16645       | 3      | RGB
# 2-62.bmp                       | 167*16221       | 3      | RGB
# 2-63.bmp                       | 121*16721       | 3      | RGB
# 2-64.bmp                       | 163*17323       | 3      | RGB
# 2-65.bmp                       | 164*16787       | 3      | RGB
# 2-66.bmp                       | 148*16431       | 3      | RGB
# 2-67.bmp                       | 140*16608       | 3      | RGB
# 2-68.bmp                       | 143*16647       | 3      | RGB
# 2-69.bmp                       | 150*16242       | 3      | RGB
# 2-7.bmp                        | 147*16324       | 3      | RGB
# 2-70.bmp                       | 169*15864       | 3      | RGB
# 2-71.bmp                       | 221*16245       | 3      | RGB
# 2-72.bmp                       | 182*16236       | 3      | RGB
# 2-73.bmp                       | 153*16828       | 3      | RGB
# 2-74.bmp                       | 196*16789       | 3      | RGB
# 2-75.bmp                       | 183*16769       | 3      | RGB
# 2-76.bmp                       | 174*16527       | 3      | RGB
# 2-77.bmp                       | 192*16215       | 3      | RGB
# 2-78.bmp                       | 203*16121       | 3      | RGB
# 2-79.bmp                       | 140*16754       | 3      | RGB
# 2-8.bmp                        | 152*16115       | 3      | RGB
# 2-80.bmp                       | 143*16754       | 3      | RGB
# 2-81.bmp                       | 148*16041       | 3      | RGB
# 2-82.bmp                       | 184*16099       | 3      | RGB
# 2-83.bmp                       | 168*16761       | 3      | RGB
# 2-84.bmp                       | 172*16088       | 3      | RGB
# 2-85.bmp                       | 137*16156       | 3      | RGB
# 2-86.bmp                       | 145*16688       | 3      | RGB
# 2-87.bmp                       | 164*16182       | 3      | RGB
# 2-88.bmp                       | 166*16370       | 3      | RGB
# 2-89.bmp                       | 161*16515       | 3      | RGB
# 2-9.bmp                        | 154*16102       | 3      | RGB
# 2-90.bmp                       | 189*16213       | 3      | RGB
# 2-91.bmp                       | 181*16111       | 3      | RGB
# 2-92.bmp                       | 160*16145       | 3      | RGB
# 2-93.bmp                       | 141*16205       | 3      | RGB
# 2-94.bmp                       | 157*16489       | 3      | RGB
# 2-95.bmp                       | 151*16259       | 3      | RGB
# 2-96.bmp                       | 144*16315       | 3      | RGB
# 2-97.bmp                       | 144*16420       | 3      | RGB
# 2-98.bmp                       | 145*16148       | 3      | RGB
# 2-99.bmp                       | 165*16086       | 3      | RGB
# ----------------------------------------------------------------------
# 扫描完成，共 150 张图片。
# 通道分布统计: {3: 150}
# D:\FL\ignore\initial\3\
# 正在深度扫描文件夹: D:\FL\ignore\initial\3\ ...
#
# 文件名                            | 尺寸 (宽x高)        | 通道数    | 模式
# ----------------------------------------------------------------------
# 3-1.bmp                        | 165*16456       | 3      | RGB
# 3-10.bmp                       | 161*16209       | 3      | RGB
# 3-11.bmp                       | 153*16132       | 3      | RGB
# 3-12.bmp                       | 151*16227       | 3      | RGB
# 3-13.bmp                       | 154*15867       | 3      | RGB
# 3-14.bmp                       | 238*16651       | 3      | RGB
# 3-15.bmp                       | 161*16643       | 3      | RGB
# 3-16.bmp                       | 172*16660       | 3      | RGB
# 3-17.bmp                       | 156*16391       | 3      | RGB
# 3-18.bmp                       | 164*16417       | 3      | RGB
# 3-19.bmp                       | 154*16693       | 3      | RGB
# 3-2.bmp                        | 167*16466       | 3      | RGB
# 3-20.bmp                       | 173*16256       | 3      | RGB
# 3-21.bmp                       | 144*16696       | 3      | RGB
# 3-22.bmp                       | 144*16526       | 3      | RGB
# 3-23.bmp                       | 142*16522       | 3      | RGB
# 3-24.bmp                       | 137*16719       | 3      | RGB
# 3-25.bmp                       | 132*16734       | 3      | RGB
# 3-26.bmp                       | 144*16615       | 3      | RGB
# 3-27.bmp                       | 159*16640       | 3      | RGB
# 3-28.bmp                       | 159*16820       | 3      | RGB
# 3-29.bmp                       | 290*16587       | 3      | RGB
# 3-3.bmp                        | 165*16438       | 3      | RGB
# 3-30.bmp                       | 170*16681       | 3      | RGB
# 3-31.bmp                       | 161*16655       | 3      | RGB
# 3-32.bmp                       | 194*16457       | 3      | RGB
# 3-33.bmp                       | 230*16720       | 3      | RGB
# 3-34.bmp                       | 199*16687       | 3      | RGB
# 3-35.bmp                       | 190*16568       | 3      | RGB
# 3-36.bmp                       | 240*16722       | 3      | RGB
# 3-37.bmp                       | 240*16710       | 3      | RGB
# 3-38.bmp                       | 249*16592       | 3      | RGB
# 3-39.bmp                       | 239*16740       | 3      | RGB
# 3-4.bmp                        | 156*16404       | 3      | RGB
# 3-40.bmp                       | 237*16603       | 3      | RGB
# 3-41.bmp                       | 240*16595       | 3      | RGB
# 3-42.bmp                       | 237*16617       | 3      | RGB
# 3-43.bmp                       | 239*16664       | 3      | RGB
# 3-44.bmp                       | 240*16673       | 3      | RGB
# 3-45.bmp                       | 238*15955       | 3      | RGB
# 3-46.bmp                       | 241*16457       | 3      | RGB
# 3-47.bmp                       | 242*16705       | 3      | RGB
# 3-48.bmp                       | 178*16403       | 3      | RGB
# 3-49.bmp                       | 169*16535       | 3      | RGB
# 3-5.bmp                        | 160*16304       | 3      | RGB
# 3-50.bmp                       | 213*16686       | 3      | RGB
# 3-6.bmp                        | 156*16178       | 3      | RGB
# 3-7.bmp                        | 168*16187       | 3      | RGB
# 3-8.bmp                        | 188*16255       | 3      | RGB
# 3-9.bmp                        | 155*16217       | 3      | RGB
# ----------------------------------------------------------------------
# 扫描完成，共 50 张图片。
# 通道分布统计: {3: 50}
# D:\FL\ignore\initial\4\
# 正在深度扫描文件夹: D:\FL\ignore\initial\4\ ...
#
# 文件名                            | 尺寸 (宽x高)        | 通道数    | 模式
# ----------------------------------------------------------------------
# 4-1.bmp                        | 162*16375       | 3      | RGB
# 4-10.bmp                       | 141*16186       | 3      | RGB
# 4-11.bmp                       | 228*16130       | 3      | RGB
# 4-12.bmp                       | 198*16341       | 3      | RGB
# 4-13.bmp                       | 161*16399       | 3      | RGB
# 4-14.bmp                       | 174*16692       | 3      | RGB
# 4-15.bmp                       | 240*16209       | 3      | RGB
# 4-16.bmp                       | 243*16011       | 3      | RGB
# 4-17.bmp                       | 132*16547       | 3      | RGB
# 4-18.bmp                       | 159*16726       | 3      | RGB
# 4-19.bmp                       | 310*16619       | 3      | RGB
# 4-2.bmp                        | 167*16465       | 3      | RGB
# 4-20.bmp                       | 182*15819       | 3      | RGB
# 4-21.bmp                       | 248*16412       | 3      | RGB
# 4-22.bmp                       | 207*16345       | 3      | RGB
# 4-23.bmp                       | 123*16768       | 3      | RGB
# 4-24.bmp                       | 142*16310       | 3      | RGB
# 4-25.bmp                       | 198*16753       | 3      | RGB
# 4-26.bmp                       | 156*16321       | 3      | RGB
# 4-27.bmp                       | 136*16569       | 3      | RGB
# 4-28.bmp                       | 141*16415       | 3      | RGB
# 4-29.bmp                       | 254*15894       | 3      | RGB
# 4-3.bmp                        | 160*16415       | 3      | RGB
# 4-30.bmp                       | 287*16128       | 3      | RGB
# 4-31.bmp                       | 260*16338       | 3      | RGB
# 4-32.bmp                       | 199*16510       | 3      | RGB
# 4-33.bmp                       | 184*16041       | 3      | RGB
# 4-34.bmp                       | 230*16369       | 3      | RGB
# 4-35.bmp                       | 150*16228       | 3      | RGB
# 4-36.bmp                       | 152*16595       | 3      | RGB
# 4-37.bmp                       | 193*15958       | 3      | RGB
# 4-38.bmp                       | 122*16316       | 3      | RGB
# 4-39.bmp                       | 243*16742       | 3      | RGB
# 4-4.bmp                        | 160*16405       | 3      | RGB
# 4-40.bmp                       | 230*15948       | 3      | RGB
# 4-41.bmp                       | 153*16314       | 3      | RGB
# 4-42.bmp                       | 155*16431       | 3      | RGB
# 4-5.bmp                        | 160*16432       | 3      | RGB
# 4-6.bmp                        | 136*16033       | 3      | RGB
# 4-7.bmp                        | 206*16257       | 3      | RGB
# 4-8.bmp                        | 120*16352       | 3      | RGB
# 4-9.bmp                        | 215*16641       | 3      | RGB
# ----------------------------------------------------------------------
# 扫描完成，共 42 张图片。
# 通道分布统计: {3: 42}
